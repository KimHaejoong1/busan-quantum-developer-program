# %%
import qiskit
import qiskit_ibm_runtime
print(f"Qiskit version: {qiskit.__version__}")
print(f"Runtime version: {qiskit_ibm_runtime.__version__}")
# Out:
# Qiskit version: 2.1.0
# Runtime version: 0.40.1

# %% [markdown]
# ## 5교시 : Transpile과 Qiskit Runtime
# ### 5-1 : FakeBackend와 Transpile
#
# Qiskit은 클라우드에 서비스 되는 실제 양자 백엔드의 노이즈 특성을 비롯한 여러가지 특성을 모사해둔 특별한 시뮬레이터를 또한 제공합니다. 이 시뮬레이터 들은 실제 백엔드의 basis gate의 종류나, 연결성 정보를 모두 지니고 있기 때문에, transpile이라는, 양자 회로를 리얼 백엔드에 실행하기 위해 변환해 주는 기능을 시험해 보기 아주 좋은 도구입니다.

# %%
from qiskit_ibm_runtime.fake_provider.fake_provider import FakeProviderForBackendV2
FakeProviderForBackendV2().backends()
# Out:
# [<qiskit_ibm_runtime.fake_provider.backends.algiers.fake_algiers.FakeAlgiers at 0x1d0f1762660>,
#  <qiskit_ibm_runtime.fake_provider.backends.almaden.fake_almaden.FakeAlmadenV2 at 0x1d0f17627b0>,
#  <qiskit_ibm_runtime.fake_provider.backends.armonk.fake_armonk.FakeArmonkV2 at 0x1d0f1762900>,
#  <qiskit_ibm_runtime.fake_provider.backends.athens.fake_athens.FakeAthensV2 at 0x1d0f1762a50>,
#  <qiskit_ibm_runtime.fake_provider.backends.auckland.fake_auckland.FakeAuckland at 0x1d0f1762ba0>,
#  <qiskit_ibm_runtime.fake_provider.backends.belem.fake_belem.FakeBelemV2 at 0x1d0f1762cf0>,
#  <qiskit_ibm_runtime.fake_provider.backends.boeblingen.fake_boeblingen.FakeBoeblingenV2 at 0x1d0f1762e40>,
#  <qiskit_ibm_runtime.fake_provider.backends.bogota.fake_bogota.FakeBogotaV2 at 0x1d0f1762f90>,
#  <qiskit_ibm_runtime.fake_provider.backends.brisbane.fake_brisbane.FakeBrisbane at 0x1d0f17630e0>,
#  <qiskit_ibm_runtime.fake_provider.backends.brooklyn.fake_brooklyn.FakeBrooklynV2 at 0x1d0f1763230>,
#  <qiskit_ibm_runtime.fake_provider.backends.burlington.fake_burlington.FakeBurlingtonV2 at 0x1d0f1763380>,
#  <qiskit_ibm_runtime.fake_provider.backends.cairo.fake_cairo.FakeCairoV2 at 0x1d0f17634d0>,
#  <qiskit_ibm_runtime.fake_provider.backends.cambridge.fake_cambridge.FakeCambridgeV2 at 0x1d0f1763620>,
#  <qiskit_ibm_runtime.fake_provider.backends.casablanca.fake_casablanca.FakeCasablancaV2 at 0x1d0f1763770>,
#  <qiskit_ibm_runtime.fake_provider.backends.cusco.fake_cusco.FakeCusco at 0x1d0f17638c0>,
#  <qiskit_ibm_runtime.fake_provider.backends.essex.fake_essex.FakeEssexV2 at 0x1d0f1763a10>,
#  <qiskit_ibm_runtime.fake_provider.backends.fez.fake_fez.FakeFez at 0x1d0f1763b60>,
#  <qiskit_ibm_runtime.fake_provider.backends.fractional.fake_fractional.FakeFractionalBackend at 0x1d0f1763cb0>,
#  <qiskit_ibm_runtime.fake_provider.backends.geneva.fake_geneva.FakeGeneva at 0x1d0f1763e00>,
#  <qiskit_ibm_runtime.fake_provider.backends.guadalupe.fake_guadalupe.FakeGuadalupeV2 at 0x1d0f2d74050>,
#  <qiskit_ibm_runtime.fake_provider.backends.hanoi.fake_hanoi.FakeHanoiV2 at 0x1d0f2d741a0>,
#  <qiskit_ibm_runtime.fake_provider.backends.jakarta.fake_jakarta.FakeJakartaV2 at 0x1d0f2d742f0>,
#  <qiskit_ibm_runtime.fake_provider.backends.johannesburg.fake_johannesburg.FakeJohannesburgV2 at 0x1d0f2d74440>,
#  <qiskit_ibm_runtime.fake_provider.backends.kawasaki.fake_kawasaki.FakeKawasaki at 0x1d0f2d74590>,
#  <qiskit_ibm_runtime.fake_provider.backends.kolkata.fake_kolkata.FakeKolkataV2 at 0x1d0f2d746e0>,
#  <qiskit_ibm_runtime.fake_provider.backends.kyiv.fake_kyiv.FakeKyiv at 0x1d0f2d74830>,
#  <qiskit_ibm_runtime.fake_provider.backends.kyoto.fake_kyoto.FakeKyoto at 0x1d0f2d74980>,
#  <qiskit_ibm_runtime.fake_provider.backends.lagos.fake_lagos.FakeLagosV2 at 0x1d0f2d74ad0>,
#  <qiskit_ibm_runtime.fake_provider.backends.lima.fake_lima.FakeLimaV2 at 0x1d0f2d74c20>,
#  <qiskit_ibm_runtime.fake_provider.backends.london.fake_london.FakeLondonV2 at 0x1d0f2d74d70>,
#  <qiskit_ibm_runtime.fake_provider.backends.manhattan.fake_manhattan.FakeManhattanV2 at 0x1d0f2d74ec0>,
#  <qiskit_ibm_runtime.fake_provider.backends.manila.fake_manila.FakeManilaV2 at 0x1d0f2d75010>,
#  <qiskit_ibm_runtime.fake_provider.backends.melbourne.fake_melbourne.FakeMelbourneV2 at 0x1d0f2d75160>,
#  <qiskit_ibm_runtime.fake_provider.backends.marrakesh.fake_marrakesh.FakeMarrakesh at 0x1d0f2d752b0>,
#  <qiskit_ibm_runtime.fake_provider.backends.montreal.fake_montreal.FakeMontrealV2 at 0x1d0f2d75400>,
#  <qiskit_ibm_runtime.fake_provider.backends.mumbai.fake_mumbai.FakeMumbaiV2 at 0x1d0f2d75550>,
#  <qiskit_ibm_runtime.fake_provider.backends.nairobi.fake_nairobi.FakeNairobiV2 at 0x1d0f2d756a0>,
#  <qiskit_ibm_runtime.fake_provider.backends.osaka.fake_osaka.FakeOsaka at 0x1d0f2d757f0>,
#  <qiskit_ibm_runtime.fake_provider.backends.oslo.fake_oslo.FakeOslo at 0x1d0f2d75940>,
#  <qiskit_ibm_runtime.fake_provider.backends.ourense.fake_ourense.FakeOurenseV2 at 0x1d0f2d75a90>,
#  <qiskit_ibm_runtime.fake_provider.backends.paris.fake_paris.FakeParisV2 at 0x1d0f2d75be0>,
#  <qiskit_ibm_runtime.fake_provider.backends.peekskill.fake_peekskill.FakePeekskill at 0x1d0f2d75d30>,
#  <qiskit_ibm_runtime.fake_provider.backends.perth.fake_perth.FakePerth at 0x1d0f2d75e80>,
#  <qiskit_ibm_runtime.fake_provider.backends.prague.fake_prague.FakePrague at 0x1d0f2d75fd0>,
#  <qiskit_ibm_runtime.fake_provider.backends.poughkeepsie.fake_poughkeepsie.FakePoughkeepsieV2 at 0x1d0f2d76120>,
#  <qiskit_ibm_runtime.fake_provider.backends.quebec.fake_quebec.FakeQuebec at 0x1d0f2d76270>,
#  <qiskit_ibm_runtime.fake_provider.backends.quito.fake_quito.FakeQuitoV2 at 0x1d0f2d763c0>,
#  <qiskit_ibm_runtime.fake_provider.backends.rochester.fake_rochester.FakeRochesterV2 at 0x1d0f2d76510>,
#  <qiskit_ibm_runtime.fake_provider.backends.rome.fake_rome.FakeRomeV2 at 0x1d0f2d76660>,
#  <qiskit_ibm_runtime.fake_provider.backends.santiago.fake_santiago.FakeSantiagoV2 at 0x1d0f2d767b0>,
#  <qiskit_ibm_runtime.fake_provider.backends.sherbrooke.fake_sherbrooke.FakeSherbrooke at 0x1d0f2d76900>,
#  <qiskit_ibm_runtime.fake_provider.backends.singapore.fake_singapore.FakeSingaporeV2 at 0x1d0f2d76a50>,
#  <qiskit_ibm_runtime.fake_provider.backends.sydney.fake_sydney.FakeSydneyV2 at 0x1d0f2d76ba0>,
#  <qiskit_ibm_runtime.fake_provider.backends.torino.fake_torino.FakeTorino at 0x1d0f2d76cf0>,
#  <qiskit_ibm_runtime.fake_provider.backends.toronto.fake_toronto.FakeTorontoV2 at 0x1d0f2d76e40>,
#  <qiskit_ibm_runtime.fake_provider.backends.valencia.fake_valencia.FakeValenciaV2 at 0x1d0f2d76f90>,
#  <qiskit_ibm_runtime.fake_provider.backends.vigo.fake_vigo.FakeVigoV2 at 0x1d0f2d770e0>,
#  <qiskit_ibm_runtime.fake_provider.backends.washington.fake_washington.FakeWashingtonV2 at 0x1d0f2d77230>,
#  <qiskit_ibm_runtime.fake_provider.backends.yorktown.fake_yorktown.FakeYorktownV2 at 0x1d0f2d77380>]

# %%
from qiskit.visualization import plot_gate_map
from qiskit_ibm_runtime.fake_provider import FakeVigoV2, FakeValenciaV2

# %%
plot_gate_map(FakeValenciaV2())

# %%
# FakeVigo의 gate map을 그려 보세요

plot_gate_map(FakeVigoV2())

# %% [markdown]
# 각 FakeBackend의 특성 들을 탐색해 봅시다. [이 문서](https://docs.quantum.ibm.com/api/qiskit/qiskit.providers.models.BackendConfiguration)를 참고해서 FakeVigo의 각각의 특성을 탐색해 봅시다.

# %%
conf = FakeVigoV2().configuration()

# %%
# 각종 특성을 탐색해 보세요
conf.basis_gates
# Out:
# ['id', 'rz', 'sx', 'x', 'cx']

# %%
conf.coupling_map
# Out:
# [[0, 1], [1, 0], [1, 2], [1, 3], [2, 1], [3, 1], [3, 4], [4, 3]]

# %% [markdown]
# ### 5-2 : Transpile
#
# 이 양자 백엔드에 양자 회로를 실행하면서 좋은 성능을 얻기 위해, 사용자가 직접 설정할수있는 tranpile 옵션이 여러가지 있습니다. 우선 다음 백엔드의 특성을 살펴 봅시다.

# %%
from qiskit.visualization import plot_error_map, plot_circuit_layout

# plot_error_map(FakeVigoV2())

from IPython.display import Image, display
img_path = "img/fakevigoErrorMap.png"
display(Image(filename=img_path))

# %% [markdown]
# Transpiler의 기능 중, 양자 회로의 큐비트를 물리적 큐비트에 매핑하는 기능을 사용해 더 나은 실행결과를 얻어 봅시다. 세개의 큐비트를 사용하는 다음의 대상 회로를 만들어 봅시다.

# %%
from qiskit import QuantumCircuit

qc=QuantumCircuit(3,3) # 3개의 큐비트와 3개의 고전 비트를 가진 양자 회로를 만듭니다.
qc.h(0) # 0번 큐비트에 하다마드 게이트를 적용합니다.
qc.cx(0,1) # 0번 큐비트를 control 1번 큐비트에 target으로 지정해 CX 게이트를 적용합니다.
qc.cx(1,2) # 1번 큐비트를 control 2번 큐비트에 target으로 지정해 CX 게이트를 적용합니다.
qc.measure([0,1,2],[0,1,2]) # 0,1,2번 큐비트를 0,1,2번 고전 비트에 측정합니다.
qc.draw(output='mpl') # 양자 회로를 그립니다

# %%
# backend에 맞게 qc 양자 회로를 transpile 해보세요.
# import 부터 시작해보세요
from qiskit import transpile
from qiskit_ibm_runtime.fake_provider import FakeVigoV2, FakeValenciaV2
from qiskit.transpiler import generate_preset_pass_manager

backend = FakeVigoV2()

#
pm = generate_preset_pass_manager(backend=backend)
isa_circuit = pm.run(qc)

isa_circuit.draw(output="mpl") # transpile한 qc 양자 회로를 그립니다.

# %%
isa_circuit = transpile(qc, backend)
isa_circuit.draw(output="mpl")

# %%
# Sampler를 이용해 양자 회로를 주어진 백엔드에서 실행해보세요.
# import 부터 시작해보세요
from qiskit_ibm_runtime import Sampler
from qiskit.visualization import plot_histogram

sampler = Sampler(mode=backend)
job = sampler.run([isa_circuit])
counts = job.result()[0].data.c.get_counts()

plot_histogram(counts)

# %% [markdown]
# transpiler를 사용해서 논리적 큐비트를 물리적 큐비트에 매핑하기 위해서는 `initial_layout`값을 설정해 줄 수 있습니다. 아래의 코드에 강제로 논리적 큐비트 0,1,2를 물리적 큐비트 0, 1,3에 매핑 한 후 plot_histogram을 그려봅시다.

# %%
pm = generate_preset_pass_manager(backend=backend, initial_layout=[0,1,3]) #
isa_circuit = pm.run(qc)
# plot_circuit_layout(isa_circuit, backend)

img_path = "img/initialLayout013.png"
display(Image(img_path))

# %% [markdown]
# transpile된 회로를 실행해서 counts를 plot_histogram으로 그려 봅시다.

# %%
#
sampler = Sampler(mode=backend)
job = sampler.run([isa_circuit])
counts = job.result()[0].data.c.get_counts()

plot_histogram(counts)

# %% [markdown]
#  transpiler는 transpile 수준을 0부터 3까지 제공합니다. 새로운 테스트용 회로를 사용해 각각의 레벨로 주어진 회로를 transpile한 후 결과를 그려 봅시다.

# %%
from math import pi

qc_trans=QuantumCircuit(3)
qc_trans.h(range(2))
qc_trans.x(2)
qc_trans.ccx(0,1,2)
qc_trans.ry(pi,0)
qc_trans.ch(1,2)
qc_trans.tdg(2)
qc_trans.cx(1,0)
qc_trans.draw(output='mpl')

# %%
#optimization_level = 0으로 회로를 transpile 한 후 회로를 그려보세요
pm_0 = generate_preset_pass_manager(backend=backend, optimization_level=0)
isa_circuit_0 = pm_0.run(qc_trans)
isa_circuit_0.draw(output="mpl") # 트랜스파일한 qc_trans 양자 회로를 그립니다.

# %%
#optimization_level = 1으로 회로를 transpile 한 후 회로를 그려보세요
pm_1 = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit_1 = pm_1.run(qc_trans)
isa_circuit_1.draw(output="mpl") # 트랜스파일한 qc_trans 양자 회로를 그립니다.

# %%
#optimization_level = 2으로 회로를 transpile 한 후 회로를 그려보세요
pm_2 = generate_preset_pass_manager(backend=backend, optimization_level=2)
isa_circuit_2 = pm_2.run(qc_trans)
isa_circuit_2.draw(output="mpl") # 트랜스파일한 qc_trans 양자 회로를 그립니다.

# %%
#optimization_level = 3으로 회로를 transpile 한 후 회로를 그려보세요
pm_3 = generate_preset_pass_manager(backend=backend, optimization_level=3)
isa_circuit_3 = pm_3.run(qc_trans)
isa_circuit_3.draw(output="mpl") # 트랜스파일한 qc_trans 양자 회로를 그립니다.

# %%
# 각각의 최적화 수준으로 transpile된 회로들의 depth와 size를 비교해 보세요.
l = [isa_circuit_0, isa_circuit_1, isa_circuit_2, isa_circuit_3]

for i in range(4):
    print(i," depth: ", l[i].depth(), " size: ", l[i].size())
# Out:
# 0  depth:  33  size:  50
# 1  depth:  23  size:  37
# 2  depth:  23  size:  34
# 3  depth:  23  size:  34

# %% [markdown]
# ### 5-3 : 실제 백엔드를 사용하는 방법
#
# 실제 백엔드를 사용하기 위해서는 Qiskit Runtime Service에 접속해서 백엔드를 불러오는 것으로, 나머지 실행 과정은 위와 동일합니다. 서비스에 접속해봅시다.

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

service = QiskitRuntimeService(name='qgss-2025') # Qiskit 런타임 서비스에 접속합니다.

# %% [markdown]
# 사용자의 계정이 사용할 수 있는 백엔드의 목록을 가져와 봅시다.

# %%
service.backends() # service에서 사용 가능한 백엔드의 목록을 불러옵니다.
# Out:
# [<IBMBackend('ibm_brisbane')>, <IBMBackend('ibm_torino')>]

# %% [markdown]
# 계정에서, `ibm_brisbane` 백엔드를 `backend()`를 사용해 불러와서 backend로 설정해 봅시다.

# %%
backend = service.backend('ibm_brisbane')
backend
# Out:
# <IBMBackend('ibm_brisbane')>

# %% [markdown]
# ibmq_provider에서 qubit의 수가 100이상인 백엔드의 목록만 가져와 봅시다.

# %%
service.backends(filters=lambda b: b.configuration().n_qubits > 100)
# Out:
# [<IBMBackend('ibm_brisbane')>, <IBMBackend('ibm_torino')>]

# %% [markdown]
# 실제 양자 장치중에서 가장 대기열이 낮은 백엔드 찾기

# %%
#
service.least_busy()
# Out:
# <IBMBackend('ibm_brisbane')>

# %% [markdown]
# ## 5-4: 백엔드로 보내진 Job의 정보의 확인

# %% [markdown]
# 실습을 위해 임의의 양자 회로를 생성해 봅니다.

# %%
from qiskit.circuit.random import random_circuit
qc = random_circuit(4, 4, measure=True)
qc.draw('mpl')

# %%
from qiskit_aer import AerSimulator
from qiskit_ibm_runtime import Sampler

backend = AerSimulator() # 백엔드를 지정합니다.
sampler = Sampler(backend)

# job = sampler.run([qc])
pm = generate_preset_pass_manager(backend=backend)
job = sampler.run([pm.run(qc)])

# %%
# job id를 출력해 봅시다.

job.job_id()
# Out:
# 'ccc95278-0e3a-4367-bb6d-e4af71c10889'

# %%
# job의  backend 정보를 확인해 봅시다.

job.backend()
# Out:
# AerSimulator('aer_simulator')

# %%
# job의 상태를 확인해 봅시다.

job.status()
# Out:
# <JobStatus.DONE: 'job has successfully run'>

# %%
# job이 완료 되었다면 결과를 다시 불러와 결과를 출력해 봅니다.

plot_histogram(job.result()[0].data.c.get_counts())

# %% [markdown]
# ## Quiz!
# 1. 다음 그림을 똑같이 만들어 보세요.
#
# ![question11](./img/ex8.png)

# %%
# 
# from qiskit_ibm_runtime.fake_provider import FakeQuitoV2
# from qiskit.visualization import plot_error_map

# backend = FakeQuitoV2()
# plot_error_map(backend)

img_path = "img/fakeQuitoErrorMap.png"
display(Image(img_path))

# %% [markdown]
# 2. 다음의 코드가 주어졌을때

# %%
from qiskit import BasicAer, Aer, execute
qc = QuantumCircuit(1)
qc.h(0)

# insert code here


print(unitary)
# Out:
# $$
#
# \begin{bmatrix}
# \frac{\sqrt{2}}{2} & \frac{\sqrt{2}}{2}  \\
#  \frac{\sqrt{2}}{2} & - \frac{\sqrt{2}}{2}  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# 다음의 결과를 출력하게 해주도록 넣을 수 있는 코드 두가지는 무엇일까요?
#
# ```
#     [[ 0.70710678+0.00000000e+00j  0.70710678-8.65956056e-17j]
#     [ 0.70710678+0.00000000e+00j -0.70710678+8.65956056e-17j]]

# %%
# A
simulator = BasicAer.get_backend('unitary_simulator')
unitary = execute(qc, simulator).get_unitary(qc)

#B
simulator = Aer.get_backend('unitary_simulator')
result = execute(qc, simulator).result()
unitary = result.get_unitary(qc)

#C
simulator = Aer.get_backend('statevector_simulator')
result = execute(qc, simulator).result()
unitary = result.get_matrix_result(qc)

#D
simulator = BasicAer.get_backend('statevector_simulator')
result = execute(qc, simulator).result()
unitary = result.get_unitary(qc)

#E
simulator = BasicAer.get_backend('unitary_simulator')
result = execute(qc, simulator).result()
unitary = result.get_unitary()

# %%
from qiskit import BasicAer, Aer, execute
qc = QuantumCircuit(1)
qc.h(0)

# insert code here
inp = input()

if inp == 'A':
    # A
    simulator = BasicAer.get_backend('unitary_simulator')
    unitary = execute(qc, simulator).get_unitary(qc)
    
elif inp == 'B':
    #B
    simulator = Aer.get_backend('unitary_simulator')
    result = execute(qc, simulator).result()
    unitary = result.get_unitary(qc)
    
elif inp == 'C':
    #C
    simulator = Aer.get_backend('statevector_simulator')
    result = execute(qc, simulator).result()
    unitary = result.get_matrix_result(qc)
    
elif inp == 'D':
    #D
    simulator = BasicAer.get_backend('statevector_simulator')
    result = execute(qc, simulator).result()
    unitary = result.get_unitary(qc)
    
elif inp == 'E':
    #E
    simulator = BasicAer.get_backend('unitary_simulator')
    result = execute(qc, simulator).result()
    unitary = result.get_unitary()

print(unitary)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 from qiskit import BasicAer, Aer, execute
#       2 qc = QuantumCircuit(1)
#       3 qc.h(0)
#
# ImportError: cannot import name 'BasicAer' from 'qiskit' (c:\WORKS\PNU\2025QiskitGlobalSummerSchool\miniconda3\envs\cwq\Lib\site-packages\qiskit\__init__.py)

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Operator, Statevector
from qiskit_aer import AerSimulator

qc = QuantumCircuit(1)
qc.h(0)

# insert code here
inp = input()

if inp == 'A':
    # A
    # simulator = BasicAer.get_backend('unitary_simulator')
    # unitary = execute(qc, simulator).get_unitary(qc)
    unitary = Operator(qc)
    
elif inp == 'B':
    #B
    # simulator = Aer.get_backend('unitary_simulator')
    # result = execute(qc, simulator).result()
    # unitary = result.get_unitary(qc)
    simulator = AerSimulator()
    qc.save_unitary()
    result = simulator.run(qc).result()
    unitary = result.get_unitary()
    
elif inp == 'C':
    #C
    # simulator = Aer.get_backend('statevector_simulator')
    # result = execute(qc, simulator).result()
    # unitary = result.get_matrix_result(qc)
    simulator = AerSimulator()
    qc.save_statevector()
    result = simulator.run(qc).result()
    unitary = result.get_statevector()
    
elif inp == 'D':
    #D
    # simulator = BasicAer.get_backend('statevector_simulator')
    # result = execute(qc, simulator).result()
    # unitary = result.get_unitary(qc)
    unitary = Statevector(qc)
    
elif inp == 'E':
    #E
    # simulator = BasicAer.get_backend('unitary_simulator')
    # result = execute(qc, simulator).result()
    # unitary = result.get_unitary()
    unitary = Operator(qc)

print(inp)
print()
print(unitary)
# Out:
# B
#
# Operator([[ 0.70710678+0.00000000e+00j,  0.70710678-8.65956056e-17j],
#           [ 0.70710678+0.00000000e+00j, -0.70710678+8.65956056e-17j]],
#          input_dims=(2,), output_dims=(2,))
